# %%
import pandas as pd
primera_semana_2024 = pd.Series(pd.date_range('20240101', periods=7))
primera_semana_2024
# Out:
# 0   2024-01-01
# 1   2024-01-02
# 2   2024-01-03
# 3   2024-01-04
# 4   2024-01-05
# 5   2024-01-06
# 6   2024-01-07
# dtype: datetime64[ns]

# %%
fechas = pd.read_csv('/Users/alejandrobueno/Documents/WWW/cursos,etc/Python/PythonTOTAL_DataScience/fechas.csv')
df = pd.DataFrame(fechas)
df['fecha'] = pd.to_datetime(df['fecha'], format="%Y-%m-%d")
df
# Out:
#        fecha
# 0 2024-01-01
# 1 2024-02-14
# 2 2024-03-01

# %%
df_mas_5_dias = df['fecha'] + pd.Timedelta(days=5)
df_mas_5_dias
# Out:
# 0   2024-01-06
# 1   2024-02-19
# 2   2024-03-06
# Name: fecha, dtype: datetime64[ns]
